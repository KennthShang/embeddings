# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, we'll using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, we'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while we're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When we're dealing with language and words, we end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, we'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then we can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [05:06, 102KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# > Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
#
# > Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# we don't actually need to do the matrix multiplication, we just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, we're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# >  Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: 无法创建目录"checkpoints": 文件已存在

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6477 0.4297 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5989 0.4266 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4911 0.4014 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5818 0.3992 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5342 0.3977 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5247 0.3984 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5439 0.3976 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5430 0.3962 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4838 0.3956 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4135 0.3979 sec/batch
# Nearest to i: neatly, norns, camira, arterial, carpenters, burnt, herculaneum, effortless,
# Nearest to who: b, weigel, dependence, fireballs, villepin, undaunted, boziz, xenia,
# Nearest to known: coerced, iowa, stritch, cryoprotectant, priestly, indication, altman, reference,
# Nearest to about: zsa, nigel, bayern, suffered, hedonistic, zia, anticipate, wyoming,
# Nearest to from: dip, ffing, facilitate, kittiwakes, selections, kev, inviolable, conjunctions,
# Nearest to also: communism, sprague, averroes, personifications, rome, second, noob, ride,
# Nearest to and: redundantly, establish, crucial, leader, ketones, transcend, dominance, quintus,
# Nearest to many: duel, ethane, gaming, arcas, pleasuredome, erit, shorts, neues,
# Nearest to institute: cosmic, aftermarket, derision, similarities, trickle, rings, transportation, propto,
# Nearest to derived: myopia, scullard, dolchsto, stallions, johns, undisturbed, suspicion, fecal,
# Nearest to defense: summarize, dispossessed, pili, unevenly, renault, scripted, numbness, crows,
# Nearest to animals: stretches, holtz, interrupt, as, pannonia, ermey, spell, giger,
# Nearest to square: nafs, oppose, rss, seahawks, dah, euphoric, vespucci, wail,
# Nearest to hold: recoiled, germaine, erudition, laureates, ptah, novi, svend, mogul,
# Nearest to ice: ethnolinguistic, wire, headstock, familycolor, finches, really, shah, atreides,
# Nearest to articles: sejong, flash, milos, reactos, detonated, set, heylin, absorb,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4835 0.4010 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3296 0.3972 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3174 0.3956 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2539 0.3938 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1456 0.3927 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1701 0.3951 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0793 0.4010 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0869 0.4018 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0033 0.3927 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9766 0.4001 sec/batch
# Nearest to i: neatly, burnt, arterial, cad, carpenters, norns, inspiring, compact,
# Nearest to who: b, dependence, executive, fireballs, finance, meaning, boziz, weigel,
# Nearest to known: half, iowa, coerced, reference, affiliate, longer, indication, priestly,
# Nearest to about: zsa, suffered, nigel, bayern, m, anticipate, bologna, distinctive,
# Nearest to from: facilitate, dip, ffing, much, selections, event, etched, support,
# Nearest to also: communism, second, rome, ride, biotechnology, sprague, doubled, return,
# Nearest to and: crucial, establish, soft, redundantly, leader, sometimes, default, transcend,
# Nearest to many: do, able, duel, gaming, shorts, increased, ethane, wins,
# Nearest to institute: rings, cosmic, similarities, man, transportation, autonomist, documents, curve,
# Nearest to derived: scullard, audience, suspicion, stallions, sound, skull, suggestions, ceased,
# Nearest to defense: summarize, dispossessed, user, unevenly, shower, crows, aerosmith, renault,
# Nearest to animals: as, stretches, interrupt, holtz, intermontane, pannonia, spell, elective,
# Nearest to square: oppose, nafs, our, south, data, seahawks, radiated, vespucci,
# Nearest to hold: recoiled, landmark, zone, laureates, restored, said, erudition, germaine,
# Nearest to ice: wire, really, unique, debt, influences, ethnolinguistic, headstock, puts,
# Nearest to articles: flash, set, sejong, really, agree, detonated, absorb, majority,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9298 0.4157 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9160 0.4224 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8586 0.4164 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8682 0.4053 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8153 0.3991 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8236 0.4069 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8090 0.4076 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7981 0.4025 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7603 0.4119 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7845 0.4019 sec/batch
# Nearest to i: neatly, burnt, arterial, cad, inspiring, carpenters, norns, historian,
# Nearest to who: b, dependence, villepin, fireballs, executive, finance, weigel, boziz,
# Nearest to known: coerced, half, iowa, affiliate, priestly, indication, reference, altman,
# Nearest to about: nigel, suffered, zsa, distinctive, anticipate, bayern, reveals, wyoming,
# Nearest to from: facilitate, dip, ffing, etched, selections, palestine, suffer, kev,
# Nearest to also: communism, sprague, second, ride, inward, averroes, rome, doubled,
# Nearest to and: soft, crucial, establish, maternal, default, disadvantage, brothers, redundantly,
# Nearest to many: duel, gaming, able, shorts, do, wants, ethane, paganism,
# Nearest to institute: rings, similarities, realizes, man, drunkenness, cosmic, circles, autonomist,
# Nearest to derived: johns, suspicion, scullard, suggestions, undisturbed, stallions, priesthood, dolchsto,
# Nearest to defense: summarize, dispossessed, user, unevenly, crows, renault, shower, majesty,
# Nearest to animals: as, stretches, elective, spell, interrupt, intermontane, holtz, pannonia,
# Nearest to square: nafs, rss, oppose, south, crumbling, our, wail, humanistic,
# Nearest to hold: germaine, recoiled, landmark, laureates, template, erudition, gambler, trout,
# Nearest to ice: really, influences, ethnolinguistic, wire, debt, unique, matching, anointed,
# Nearest to articles: flash, sejong, really, sway, detonated, set, ritual, commissioning,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7840 0.4032 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7439 0.4045 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7204 0.3976 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7047 0.3933 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7629 0.3966 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7197 0.4074 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6947 0.4108 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7378 0.4119 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7045 0.4079 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6625 0.3981 sec/batch
# Nearest to i: neatly, burnt, inspiring, arterial, carpenters, stingray, cad, effortless,
# Nearest to who: b, weigel, astrologer, fireballs, dependence, relator, lyricist, boziz,
# Nearest to known: coerced, half, priestly, iowa, affiliate, altman, cryoprotectant, reference,
# Nearest to about: zsa, nigel, suffered, distinctive, wyoming, bayern, anticipate, m,
# Nearest to from: dip, palestine, ffing, etched, facilitate, northern, kittiwakes, conjunctions,
# Nearest to also: communism, sprague, averroes, inward, second, ride, doubled, julia,
# Nearest to and: disadvantage, maternal, establish, crucial, soft, hesitation, default, shoe,
# Nearest to many: duel, lola, gaming, paganism, faroese, quips, afternoon, troop,
# Nearest to institute: realizes, rings, similarities, drunkenness, expressways, clarion, man, pannonia,
# Nearest to derived: scullard, undisturbed, johns, myopia, dolchsto, stallions, ethnographic, task,
# Nearest to defense: summarize, unevenly, dispossessed, crows, renault, user, kuwait, pili,
# Nearest to animals: as, stretches, elective, holtz, pannonia, spell, intermontane, arian,
# Nearest to square: nafs, rss, wail, south, oppose, crumbling, seahawks, coulsdon,
# Nearest to hold: germaine, recoiled, ptah, landmark, laureates, template, gambler, morin,
# Nearest to ice: ethnolinguistic, shah, wire, really, eliza, anointed, vigorous, melts,
# Nearest to articles: sejong, flash, sway, commissioning, really, milos, pdes, coatings,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6697 0.4045 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6687 0.3954 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5997 0.3997 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6379 0.3915 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6512 0.3906 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6481 0.3901 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5888 0.2820 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5705 0.3919 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5134 0.3910 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5159 0.3930 sec/batch
# Nearest to i: neatly, burnt, inspiring, stingray, cad, effortless, merina, ex,
# Nearest to who: weigel, boziz, astrologer, relator, ostend, beaten, transcendent, dependence,
# Nearest to known: coerced, half, priestly, iowa, reference, affiliate, altman, rave,
# Nearest to about: zsa, distinctive, allude, suffered, nigel, wyoming, anticipate, m,
# Nearest to from: dip, palestine, recreation, ffing, allegiances, northern, conjunctions, pep,
# Nearest to also: communism, sprague, averroes, inward, second, noob, metastatic, ride,
# Nearest to and: crucial, soft, maternal, disadvantage, redundantly, recreation, establish, restless,
# Nearest to many: paganism, shortcuts, gaming, quips, faroese, duel, neues, lola,
# Nearest to institute: realizes, expressways, clarion, man, pannonia, rings, notified, transformer,
# Nearest to derived: scullard, ethnographic, undisturbed, myopia, stallions, sound, suggestions, task,
# Nearest to defense: summarize, unevenly, crows, dispossessed, renault, user, pili, aerosmith,
# Nearest to animals: as, stretches, holtz, elective, rac, intermontane, spell, interrupt,
# Nearest to square: nafs, rss, south, wail, eloped, hey, lunel, coulsdon,
# Nearest to hold: germaine, recoiled, ptah, morin, landmark, mogul, gambler, laureates,
# Nearest to ice: ethnolinguistic, shah, eliza, wire, melts, vigorous, really, samoans,
# Nearest to articles: sejong, flash, really, commissioning, pdes, milos, sway, ritual,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4902 0.4095 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4818 0.3948 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4430 0.3913 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5286 0.3894 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4727 0.3895 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4803 0.3888 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4644 0.3894 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4065 0.3904 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4066 0.3891 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4517 0.3891 sec/batch
# Nearest to i: neatly, stingray, burnt, effortless, merina, inspiring, ex, cad,
# Nearest to who: boziz, weigel, ostend, beaten, astrologer, transcendent, relator, proud,
# Nearest to known: half, coerced, priestly, altman, meda, reference, cryoprotectant, stritch,
# Nearest to about: zsa, distinctive, wyoming, clog, m, anticipate, allude, hordes,
# Nearest to from: dip, northern, allegiances, ffing, much, palestine, castrated, dominant,
# Nearest to also: communism, sprague, averroes, second, noob, inward, biotechnology, wiser,
# Nearest to and: disadvantage, crucial, soft, antiquity, maternal, hesitation, loma, establish,
# Nearest to many: neues, paganism, shortcuts, lola, faroese, instead, quips, pleasuredome,
# Nearest to institute: expressways, clarion, university, danza, pannonia, notified, demonstration, realizes,
# Nearest to derived: scullard, undisturbed, updating, sound, bothered, steps, disclaimers, myopia,
# Nearest to defense: summarize, unevenly, renault, pili, dispossessed, crows, user, numbness,
# Nearest to animals: as, stretches, rac, intermontane, holtz, developmental, jigs, elective,
# Nearest to square: nafs, rss, south, city, wail, eloped, hey, coulsdon,
# Nearest to hold: recoiled, germaine, ptah, morin, landmark, property, westmoreland, librarians,
# Nearest to ice: ethnolinguistic, wire, melts, shah, samoans, pouches, vigorous, occupying,
# Nearest to articles: sejong, flash, really, milos, pdes, commissioning, sway, coatings,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4189 0.3934 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4180 0.3903 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4260 0.3900 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3976 0.3881 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4055 0.3911 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4422 0.3943 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3990 0.3946 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3633 0.3940 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4202 0.3936 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3937 0.3957 sec/batch
# Nearest to i: neatly, stingray, burnt, merina, effortless, bayesian, inspiring, cad,
# Nearest to who: weigel, boziz, ostend, transcendent, beaten, shenouda, allusion, dwarf,
# Nearest to known: half, coerced, redeemer, meda, cryoprotectant, reference, altman, stritch,
# Nearest to about: zsa, distinctive, allude, wyoming, clog, weathered, anticipate, improvisation,
# Nearest to from: dip, allegiances, ffing, etched, dominant, facilitate, northern, palestine,
# Nearest to also: communism, sprague, inward, noob, averroes, frontal, wiser, biotechnology,
# Nearest to and: disadvantage, crucial, renting, driessen, hesitation, magazine, maternal, restless,
# Nearest to many: paganism, neues, shortcuts, noncommercial, instead, erit, lola, do,
# Nearest to institute: university, expressways, clarion, danza, carolina, demonstration, centromere, james,
# Nearest to derived: scullard, updating, sound, disclaimers, expressed, undisturbed, ethnographic, myopia,
# Nearest to defense: summarize, unevenly, pili, renault, dispossessed, numbness, user, crows,
# Nearest to animals: as, stretches, rac, developmental, intermontane, delusions, lowering, holtz,
# Nearest to square: nafs, rss, south, wail, city, coulsdon, eloped, dinars,
# Nearest to hold: recoiled, not, germaine, ptah, morin, identification, property, terracotta,
# Nearest to ice: ethnolinguistic, melts, wire, samoans, pouches, lactation, fortunate, ores,
# Nearest to articles: sejong, really, flash, pdes, milos, unicode, substantive, koopman,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3798 0.3974 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4083 0.3943 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3612 0.3943 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3626 0.3935 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3840 0.3940 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3479 0.3957 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4137 0.3943 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3859 0.3933 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3156 0.3941 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3504 0.3925 sec/batch
# Nearest to i: neatly, stingray, burnt, effortless, bayesian, merina, inspiring, you,
# Nearest to who: weigel, boziz, wrath, astrologer, transcendent, ostend, shenouda, beaten,
# Nearest to known: half, cryoprotectant, coerced, redeemer, altman, meda, stritch, reference,
# Nearest to about: wyoming, distinctive, allude, zsa, clog, weathered, bayern, anticipate,
# Nearest to from: dip, allegiances, northern, ffing, facilitate, palestine, much, dactylic,
# Nearest to also: communism, sprague, averroes, frontal, wiser, second, gattaca, noob,
# Nearest to and: irregulars, establish, driessen, renting, disadvantage, restless, provable, theistic,
# Nearest to many: paganism, neues, noncommercial, instead, erit, pleasuredome, shortcuts, machining,
# Nearest to institute: university, expressways, clarion, carolina, abelson, james, notified, danza,
# Nearest to derived: scullard, sound, myopia, ethnographic, disclaimers, updating, undisturbed, expressed,
# Nearest to defense: pili, summarize, unevenly, renault, telegraphic, user, dispossessed, kuwait,
# Nearest to animals: stretches, as, rac, developmental, intermontane, lowering, jigs, delusions,
# Nearest to square: nafs, rss, south, city, wail, eloped, coulsdon, zangger,
# Nearest to hold: ptah, recoiled, germaine, not, morin, property, librarians, eil,
# Nearest to ice: melts, ethnolinguistic, wire, samoans, pouches, crude, ores, lactation,
# Nearest to articles: sejong, flash, really, milos, pdes, unicode, substantive, ritual,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3072 0.3975 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3033 0.3983 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3746 0.3960 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3702 0.3936 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3888 0.3928 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2779 0.3914 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3053 0.3881 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3344 0.3905 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2103 0.3896 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2700 0.3896 sec/batch
# Nearest to i: neatly, stingray, burnt, inspiring, you, effortless, merina, bard,
# Nearest to who: weigel, boziz, wrath, ostend, transcendent, shenouda, szl, chthonic,
# Nearest to known: half, cryoprotectant, redeemer, altman, coerced, reference, stritch, meda,
# Nearest to about: distinctive, allude, bombay, wyoming, proc, bayern, purposefully, improvisation,
# Nearest to from: dip, allegiances, facilitate, shenouda, castrated, northern, dactylic, ffing,
# Nearest to also: communism, sprague, wiser, economical, frontal, second, baked, aggadah,
# Nearest to and: irregulars, establish, disadvantage, restless, grattan, theistic, magazine, renting,
# Nearest to many: paganism, pleasuredome, neues, noncommercial, erit, shortcuts, quips, instead,
# Nearest to institute: university, abelson, expressways, clarion, james, centromere, science, carolina,
# Nearest to derived: scullard, ethnographic, myopia, sound, negotiable, consonant, updating, magisterial,
# Nearest to defense: summarize, pili, renault, unevenly, dispossessed, telegraphic, kuwait, user,
# Nearest to animals: stretches, developmental, rac, intermontane, delusions, jigs, as, lowering,
# Nearest to square: rss, nafs, south, wail, city, dinars, coulsdon, eloped,
# Nearest to hold: recoiled, ptah, property, germaine, morin, not, epimenides, forebears,
# Nearest to ice: melts, ethnolinguistic, wire, samoans, pouches, fielders, bluish, crude,
# Nearest to articles: sejong, milos, really, pdes, flash, substantive, unicode, coverage,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3094 0.3930 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3126 0.3902 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3172 0.1720 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2476 0.3890 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2431 0.3901 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2316 0.3906 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2140 0.3889 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2192 0.3898 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2250 0.3897 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1864 0.3892 sec/batch
# Nearest to i: neatly, burnt, stingray, effortless, inspiring, you, abstention, merina,
# Nearest to who: weigel, boziz, wrath, transcendent, chthonic, errand, dismantle, allusion,
# Nearest to known: half, cryoprotectant, coerced, redeemer, meda, priestly, altman, reference,
# Nearest to about: wyoming, proc, allude, m, distinctive, senegal, people, bombay,
# Nearest to from: shenouda, dip, banting, northern, dominant, allegiances, gaelic, scattered,
# Nearest to also: communism, baked, economical, sprague, frontal, wiser, second, noob,
# Nearest to and: irregulars, disadvantage, lieder, restless, soft, recreation, theistic, occ,
# Nearest to many: paganism, erit, pleasuredome, neues, afternoon, frowned, quips, practices,
# Nearest to institute: university, abelson, michell, clarion, science, centromere, research, expressways,
# Nearest to derived: scullard, ethnographic, myopia, negotiable, conics, sound, implies, century,
# Nearest to defense: summarize, pili, renault, unevenly, defensive, kuwait, telegraphic, check,
# Nearest to animals: stretches, delusions, jigs, as, rac, developmental, intermontane, lowering,
# Nearest to square: rss, nafs, south, wail, city, eloped, border, coulsdon,
# Nearest to hold: ptah, recoiled, property, germaine, morin, epimenides, not, eil,
# Nearest to ice: melts, ethnolinguistic, samoans, wire, pouches, fielders, eliza, bluish,
# Nearest to articles: sejong, milos, substantive, japonic, pdes, coverage, koopman, really,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2588 0.3934 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2157 0.3892 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2186 0.3902 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0936 0.3896 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1640 0.3884 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1746 0.3892 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1698 0.3877 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1962 0.3897 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2058 0.4173 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1733 0.3894 sec/batch
# Nearest to i: neatly, burnt, you, stingray, if, vpn, effortless, abstention,
# Nearest to who: weigel, boziz, wrath, transcendent, chthonic, errand, silent, willful,
# Nearest to known: reference, half, altman, cryoprotectant, redeemer, meda, hutchence, stritch,
# Nearest to about: wyoming, allude, proc, distinctive, purposefully, amigas, m, appreciative,
# Nearest to from: dip, banting, allegiances, dominant, shenouda, gaelic, kittiwakes, castrated,
# Nearest to also: communism, economical, frontal, baked, aggadah, second, gattaca, merges,
# Nearest to and: disadvantage, theistic, irregulars, kahanamoku, lieder, trixie, provable, complacent,
# Nearest to many: paganism, erit, noncommercial, shortcuts, neues, pleasuredome, gaming, quips,
# Nearest to institute: university, research, abelson, science, california, carolina, michell, clarion,
# Nearest to derived: scullard, ethnographic, century, implies, negotiable, consonant, sound, updating,
# Nearest to defense: summarize, pili, defensive, telegraphic, numbness, taverne, unevenly, saban,
# Nearest to animals: stretches, rac, delusions, intermontane, as, developmental, lowering, fungi,
# Nearest to square: rss, nafs, south, city, zangger, border, wail, kilometers,
# Nearest to hold: recoiled, ptah, property, germaine, morin, epimenides, not, said,
# Nearest to ice: melts, ethnolinguistic, samoans, bluish, wire, pouches, fielders, soft,
# Nearest to articles: sejong, milos, really, japonic, catholic, koopman, coverage, pdes,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1943 0.3919 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2277 0.3889 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1859 0.3904 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1849 0.3886 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1710 0.3889 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1704 0.3875 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2249 0.3900 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1777 0.3893 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1118 0.3905 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1727 0.3899 sec/batch
# Nearest to i: neatly, you, stingray, burnt, vpn, pah, ex, de,
# Nearest to who: weigel, boziz, wrath, transcendent, chthonic, szl, cherokees, willful,
# Nearest to known: altman, half, cryoprotectant, meda, reference, hutchence, redeemer, heliopause,
# Nearest to about: allude, wyoming, bayern, bombay, distinctive, proc, purposefully, m,
# Nearest to from: allegiances, dactylic, shenouda, dominant, gaelic, dip, banting, palestine,
# Nearest to also: communism, baked, aggadah, noob, economical, sprague, engrossed, frontal,
# Nearest to and: disadvantage, hodges, irregulars, theistic, provable, trixie, renting, lieder,
# Nearest to many: paganism, erit, machining, noncommercial, neues, gaming, quips, term,
# Nearest to institute: university, research, abelson, california, science, carolina, michell, clarion,
# Nearest to derived: scullard, ethnographic, consonant, century, implies, sound, rrs, conics,
# Nearest to defense: summarize, pili, telegraphic, defensive, air, taverne, dispossessed, businessmen,
# Nearest to animals: stretches, delusions, rac, fungi, as, developmental, intermontane, flagella,
# Nearest to square: rss, nafs, south, city, zangger, kilometers, coulsdon, wail,
# Nearest to hold: recoiled, property, ptah, not, morin, germaine, epimenides, proton,
# Nearest to ice: melts, ethnolinguistic, bluish, samoans, pouches, fielders, soft, hemisphere,
# Nearest to articles: sejong, really, wikipedia, koopman, publishing, flash, encyclopedia, milos,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2078 0.3915 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1650 0.3928 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1742 0.4049 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1768 0.3983 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1335 0.4180 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1389 0.3999 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1483 0.3948 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1150 0.3963 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1766 0.3931 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2250 0.3935 sec/batch
# Nearest to i: neatly, you, burnt, stingray, tattoo, vpn, ex, paupers,
# Nearest to who: weigel, boziz, wrath, transcendent, szl, karamchand, errand, gillies,
# Nearest to known: altman, half, cryoprotectant, meda, hutchence, reference, redeemer, heliopause,
# Nearest to about: bayern, allude, wyoming, bombay, senegal, distinctive, proc, zsa,
# Nearest to from: shenouda, banting, allegiances, dominant, palestine, dactylic, dip, handicrafts,
# Nearest to also: communism, aggadah, engrossed, baked, averroes, sprague, lancashire, second,
# Nearest to and: irregulars, the, driessen, shaker, lieder, leader, establish, kahanamoku,
# Nearest to many: paganism, erit, neues, frowned, noncommercial, paternalism, quips, ideology,
# Nearest to institute: university, abelson, california, research, science, carolina, michell, clarion,
# Nearest to derived: scullard, ethnographic, consonant, sound, rrs, myopia, negotiable, century,
# Nearest to defense: summarize, businessmen, dispossessed, misconduct, kuwait, pili, agave, telegraphic,
# Nearest to animals: stretches, delusions, intermontane, rac, developmental, jigs, flagella, fungi,
# Nearest to square: rss, nafs, south, kilometers, city, zangger, outlying, wail,
# Nearest to hold: ptah, recoiled, germaine, property, morin, not, epimenides, forebears,
# Nearest to ice: melts, ethnolinguistic, pouches, bluish, samoans, wire, fielders, soft,
# Nearest to articles: sejong, koopman, wikipedia, flash, encyclopedia, milos, japonic, really,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2405 0.3948 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1407 0.3928 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1434 0.3901 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1055 0.3943 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0294 0.4230 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1472 0.4062 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1586 0.3934 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1181 0.3948 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1713 0.0636 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1144 0.3942 sec/batch
# Nearest to i: you, neatly, ex, if, burnt, vpn, paupers, tattoo,
# Nearest to who: weigel, boziz, wrath, transcendent, errand, karamchand, chthonic, szl,
# Nearest to known: altman, meda, half, reference, hutchence, cryoprotectant, mesocricetus, heliopause,
# Nearest to about: proc, allude, bayern, fieldwork, wyoming, m, bombay, irreverent,
# Nearest to from: banting, shenouda, dip, dominant, northern, allegiances, handicrafts, kahanamoku,
# Nearest to also: communism, aggadah, baked, frontal, economical, wiser, livermore, engrossed,
# Nearest to and: the, establish, theistic, kahanamoku, eutheria, irregulars, shaker, venues,
# Nearest to many: paganism, erit, frowned, gaming, noncommercial, term, paternalism, somewhat,
# Nearest to institute: university, abelson, research, laboratory, carolina, michell, cognitive, science,
# Nearest to derived: scullard, ethnographic, rrs, consonant, ta, sound, myopia, century,
# Nearest to defense: summarize, defensive, dispossessed, taverne, misconduct, businessmen, air, agave,
# Nearest to animals: delusions, animal, aquatic, stretches, developmental, rac, intermontane, jigs,
# Nearest to square: rss, nafs, city, south, zangger, outlying, kilometers, coulsdon,
# Nearest to hold: property, recoiled, ptah, germaine, not, morin, said, epimenides,
# Nearest to ice: melts, ethnolinguistic, pouches, bluish, samoans, fielders, riverbed, hockey,
# Nearest to articles: sejong, koopman, wikipedia, flash, japonic, milos, publishing, encyclopedia,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0766 0.3954 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0695 0.4208 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0766 0.3966 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0726 0.3969 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0902 0.3982 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0579 0.3933 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0960 0.3920 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0978 0.3904 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1262 0.3923 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0433 0.3946 sec/batch
# Nearest to i: you, neatly, if, ex, paupers, burnt, sins, vpn,
# Nearest to who: boziz, weigel, wrath, transcendent, chthonic, errand, karamchand, gillies,
# Nearest to known: altman, hutchence, half, meda, cryoprotectant, mesocricetus, reference, kilometer,
# Nearest to about: proc, wyoming, m, bayern, pampa, bombay, irreverent, twine,
# Nearest to from: dip, shenouda, banting, dominant, accelerates, much, palestine, gpled,
# Nearest to also: communism, aggadah, baked, lancashire, roden, averroes, second, economical,
# Nearest to and: the, eutheria, kahanamoku, establish, disadvantage, with, theistic, eastern,
# Nearest to many: paganism, erit, gaming, term, noncommercial, paternalism, pleasuredome, somewhat,
# Nearest to institute: university, research, abelson, polytechnic, carolina, california, michell, cognitive,
# Nearest to derived: scullard, ethnographic, rrs, consist, conics, negotiable, consonant, ta,
# Nearest to defense: summarize, defensive, taverne, air, dispossessed, weapons, pili, businessmen,
# Nearest to animals: animal, developmental, delusions, aquatic, fungi, intermontane, rac, jigs,
# Nearest to square: rss, nafs, city, outlying, south, kilometers, zangger, wail,
# Nearest to hold: property, not, recoiled, ptah, epimenides, said, germaine, proton,
# Nearest to ice: melts, ethnolinguistic, pouches, samoans, bluish, riverbed, hockey, centris,
# Nearest to articles: sejong, koopman, wikipedia, milos, japonic, encyclopedia, publishing, pdes,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0177 0.3974 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0365 0.3930 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0046 0.3929 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0741 0.3935 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0820 0.3940 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0714 0.3929 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0541 0.3930 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1045 0.3932 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0575 0.3946 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0652 0.3936 sec/batch
# Nearest to i: you, neatly, if, t, vpn, paupers, ex, leq,
# Nearest to who: boziz, weigel, wrath, chthonic, transcendent, karamchand, errand, gang,
# Nearest to known: redirects, meda, altman, half, hutchence, reference, underflow, cryoprotectant,
# Nearest to about: fieldwork, proc, m, wyoming, pampa, bayern, twine, looking,
# Nearest to from: shenouda, dip, banting, gpled, dactylic, dominant, synchronous, much,
# Nearest to also: communism, aggadah, baked, rupees, livermore, order, noob, economical,
# Nearest to and: the, disadvantage, renting, theistic, venues, dashboard, eutheria, establish,
# Nearest to many: paganism, gaming, erit, noncommercial, somewhat, term, quips, frowned,
# Nearest to institute: university, polytechnic, california, carolina, technology, research, abelson, clarion,
# Nearest to derived: scullard, ethnographic, conics, rrs, consonant, consist, negotiable, implies,
# Nearest to defense: summarize, defensive, taverne, dispossessed, misconduct, weapons, businessmen, air,
# Nearest to animals: animal, aquatic, developmental, intermontane, delusions, fungi, carnivores, rac,
# Nearest to square: rss, nafs, city, outlying, kilometers, south, wail, lunel,
# Nearest to hold: recoiled, property, ptah, replace, germaine, restriction, not, morin,
# Nearest to ice: melts, ethnolinguistic, pouches, bluish, hockey, samoans, hemisphere, soft,
# Nearest to articles: koopman, sejong, wikipedia, flash, really, pdes, encyclopedia, publishing,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0422 0.3978 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0882 0.3938 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0420 0.3955 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0529 0.3938 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0782 0.3958 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0423 0.3944 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0597 0.3933 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0599 0.3965 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0834 0.3949 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0780 0.3949 sec/batch
# Nearest to i: you, neatly, if, t, my, ex, vpn, tattoo,
# Nearest to who: boziz, weigel, wrath, transcendent, szl, chthonic, karamchand, errand,
# Nearest to known: altman, redirects, meda, mentewab, cryoprotectant, half, hutchence, redeemer,
# Nearest to about: fieldwork, pampa, wyoming, looking, m, proc, bayern, fisherman,
# Nearest to from: shenouda, dominant, much, the, dactylic, palestine, allegiances, gaelic,
# Nearest to also: communism, aggadah, averroes, sylvian, rupees, order, levantine, italic,
# Nearest to and: the, establish, with, renting, eutheria, bretons, theistic, eastern,
# Nearest to many: paganism, erit, gaming, somewhat, term, quips, neues, machining,
# Nearest to institute: university, polytechnic, california, carolina, technology, clarion, abelson, research,
# Nearest to derived: scullard, ethnographic, rrs, conics, consist, ta, negotiable, sound,
# Nearest to defense: summarize, taverne, defensive, misconduct, dispossessed, air, agave, weapons,
# Nearest to animals: animal, developmental, aquatic, intermontane, delusions, fungi, echinoderms, carnivores,
# Nearest to square: rss, nafs, outlying, city, wail, tripled, coulsdon, lunel,
# Nearest to hold: recoiled, property, ptah, not, replace, fringed, morin, germaine,
# Nearest to ice: melts, ethnolinguistic, pouches, hockey, bluish, should, riverbed, soft,
# Nearest to articles: wikipedia, koopman, sejong, flash, really, pdes, coverage, publishing,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0499 0.3980 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0163 0.3951 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0421 0.3931 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0553 0.3971 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0820 0.3969 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1178 0.3952 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1489 0.3941 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0588 0.3950 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0316 0.3939 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0494 0.3912 sec/batch
# Nearest to i: you, neatly, if, t, tattoo, paupers, vpn, my,
# Nearest to who: boziz, weigel, wrath, transcendent, gillies, karamchand, szl, promiscuous,
# Nearest to known: altman, redirects, meda, cryoprotectant, mentewab, ecclesiasticus, hutchence, half,
# Nearest to about: wyoming, pampa, fieldwork, looking, fisherman, bayern, bombay, m,
# Nearest to from: shenouda, dactylic, dip, gpled, dominant, palestine, banting, handicrafts,
# Nearest to also: communism, aggadah, order, lancashire, engrossed, averroes, baked, rupees,
# Nearest to and: the, machpelah, with, establish, renting, zither, eutheria, theistic,
# Nearest to many: paganism, erit, quips, somewhat, frowned, term, gaming, playwrights,
# Nearest to institute: university, polytechnic, carolina, clarion, technology, california, abelson, michell,
# Nearest to derived: scullard, ethnographic, rrs, consonant, sound, ta, conics, consist,
# Nearest to defense: summarize, taverne, dispossessed, weapons, misconduct, air, defensive, marian,
# Nearest to animals: developmental, animal, intermontane, aquatic, ascanian, echinoderms, carnivores, fungi,
# Nearest to square: rss, nafs, outlying, city, wail, coulsdon, lunel, kilometers,
# Nearest to hold: recoiled, ptah, property, germaine, replace, not, eil, epimenides,
# Nearest to ice: melts, hockey, ethnolinguistic, pouches, bluish, soft, riverbed, fielders,
# Nearest to articles: wikipedia, sejong, koopman, flash, really, japonic, substantive, pdes,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9931 0.3980 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0032 0.3946 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0456 0.3947 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0346 0.3947 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0758 0.3948 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0219 0.3475 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9981 0.3946 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0027 0.3958 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0030 0.3952 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9773 0.3947 sec/batch
# Nearest to i: you, neatly, if, paupers, hostilities, my, vy, moesia,
# Nearest to who: boziz, wrath, weigel, transcendent, promiscuous, karamchand, chthonic, gillies,
# Nearest to known: altman, redirects, meda, mentewab, cryoprotectant, half, varying, hutchence,
# Nearest to about: fieldwork, looking, m, trench, wyoming, proc, bayern, giessen,
# Nearest to from: shenouda, dactylic, dominant, bouvet, kittiwakes, the, schama, much,
# Nearest to also: communism, aggadah, for, order, as, sylvian, levantine, lancashire,
# Nearest to and: the, with, theistic, eutheria, machpelah, lieder, establish, zither,
# Nearest to many: paganism, gaming, erit, quips, shorts, frowned, somewhat, term,
# Nearest to institute: university, technology, polytechnic, carolina, laboratory, clarion, california, michell,
# Nearest to derived: scullard, ethnographic, rrs, consist, conics, frysl, sound, undisturbed,
# Nearest to defense: summarize, taverne, defensive, weapons, air, schottenheimer, dispossessed, misconduct,
# Nearest to animals: aquatic, animal, echinoderms, developmental, intermontane, carnivores, pets, elective,
# Nearest to square: rss, nafs, outlying, city, wail, coulsdon, tallest, lunel,
# Nearest to hold: recoiled, property, ptah, replace, germaine, not, epimenides, landmark,
# Nearest to ice: hockey, melts, ethnolinguistic, pouches, riverbed, hosting, samoans, bluish,
# Nearest to articles: wikipedia, sejong, koopman, substantive, really, japonic, flash, coverage,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9989 0.3979 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9522 0.3934 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0016 0.3942 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0347 0.3950 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0063 0.3936 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0033 0.3944 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9184 0.3947 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9770 0.3938 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9532 0.3936 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9637 0.3946 sec/batch
# Nearest to i: you, neatly, if, t, my, vpn, tattoo, hostilities,
# Nearest to who: boziz, wrath, weigel, promiscuous, chthonic, karamchand, transcendent, gillies,
# Nearest to known: altman, redirects, tripled, meda, cryoprotectant, mentewab, half, ecclesiasticus,
# Nearest to about: wyoming, fieldwork, pampa, looking, trench, m, giessen, bayern,
# Nearest to from: shenouda, dip, the, dominant, bouvet, dactylic, halal, kittiwakes,
# Nearest to also: communism, for, aggadah, as, in, cve, rupees, order,
# Nearest to and: the, with, theistic, in, establish, eutheria, venues, phenyl,
# Nearest to many: paganism, erit, term, well, somewhat, quips, gaming, noncommercial,
# Nearest to institute: university, technology, polytechnic, california, carolina, research, clarion, nanyang,
# Nearest to derived: scullard, consist, rrs, ethnographic, frysl, conics, consonant, reducing,
# Nearest to defense: summarize, taverne, defensive, weapons, schottenheimer, air, dispossessed, misconduct,
# Nearest to animals: aquatic, animal, echinoderms, developmental, holtz, elective, carnivores, intermontane,
# Nearest to square: rss, outlying, nafs, city, coulsdon, tallest, tripled, wail,
# Nearest to hold: property, recoiled, landmark, not, replace, disqualified, ptah, fringed,
# Nearest to ice: hockey, melts, ethnolinguistic, should, pouches, hosting, riverbed, fielders,
# Nearest to articles: wikipedia, sejong, koopman, substantive, coverage, encyclopedia, really, flash,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9996 0.3978 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0071 0.3923 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9529 0.3922 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9956 0.3928 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0408 0.3942 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9427 0.3951 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9880 0.3944 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0026 0.3943 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9742 0.3957 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0400 0.3936 sec/batch
# Nearest to i: you, neatly, t, my, if, vy, tattoo, hostilities,
# Nearest to who: boziz, wrath, weigel, promiscuous, karamchand, gillies, onesimus, ostend,
# Nearest to known: redirects, altman, meda, ecclesiasticus, tripled, secret, hutchence, mentewab,
# Nearest to about: looking, fieldwork, pampa, wyoming, fisherman, trench, bayern, proc,
# Nearest to from: shenouda, dominant, gpled, the, bouvet, dip, curator, dactylic,
# Nearest to also: communism, for, aggadah, as, of, order, in, lancashire,
# Nearest to and: the, with, in, machpelah, for, venues, of, freeh,
# Nearest to many: paganism, somewhat, technicians, erit, such, gaming, noncommercial, playwrights,
# Nearest to institute: university, technology, polytechnic, california, carolina, clarion, nanyang, univ,
# Nearest to derived: scullard, frysl, consist, ethnographic, rrs, consonant, conics, pronominal,
# Nearest to defense: summarize, taverne, defensive, schottenheimer, misconduct, dispossessed, weapons, air,
# Nearest to animals: aquatic, echinoderms, animal, elective, intermontane, flagella, developmental, holtz,
# Nearest to square: rss, nafs, outlying, city, coulsdon, wail, tallest, lunel,
# Nearest to hold: property, recoiled, replace, not, landmark, fringed, disqualified, ptah,
# Nearest to ice: hockey, melts, ethnolinguistic, pouches, hosting, should, riverbed, fielders,
# Nearest to articles: wikipedia, sejong, koopman, really, article, coverage, substantive, flash,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0168 0.3982 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0017 0.3945 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9849 0.3945 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9808 0.3960 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0141 0.3957 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9732 0.3963 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9855 0.3947 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9638 0.3950 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9504 0.3927 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9920 0.3958 sec/batch
# Nearest to i: you, neatly, t, my, if, vy, tattoo, vpn,
# Nearest to who: boziz, wrath, weigel, transcendent, promiscuous, onesimus, executive, karamchand,
# Nearest to known: ecclesiasticus, redirects, altman, mentewab, meda, tripled, half, cryoprotectant,
# Nearest to about: fieldwork, looking, pampa, bayern, wyoming, bombay, proc, demographic,
# Nearest to from: shenouda, the, dip, bouvet, palestine, walvis, dominant, much,
# Nearest to also: communism, for, aggadah, as, of, baked, lancashire, levantine,
# Nearest to and: the, with, of, in, establish, for, specific, hodges,
# Nearest to many: paganism, somewhat, onwards, such, technicians, erit, machining, playwrights,
# Nearest to institute: university, technology, carolina, polytechnic, california, clarion, tridactyla, nanyang,
# Nearest to derived: scullard, ethnographic, frysl, rrs, consist, sound, consonant, pronominal,
# Nearest to defense: summarize, taverne, weapons, dispossessed, misconduct, schottenheimer, defensive, crows,
# Nearest to animals: animal, aquatic, echinoderms, flagella, pets, wildlife, intermontane, developmental,
# Nearest to square: rss, nafs, outlying, city, coulsdon, kilometers, tripled, tallest,
# Nearest to hold: recoiled, fringed, replace, property, ptah, rabbis, disqualified, germaine,
# Nearest to ice: hockey, ethnolinguistic, melts, should, hosting, pouches, riverbed, sheets,
# Nearest to articles: wikipedia, sejong, koopman, really, article, pornographic, substantive, coverage,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9664 0.4019 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0762 0.3955 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0304 0.3945 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0482 0.3934 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9660 0.3947 sec/batch
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8150 0.3904 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7910 0.3885 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8485 0.3885 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8723 0.3880 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8467 0.3899 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8472 0.3906 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9244 0.3899 sec/batch
# Nearest to i: my, you, we, t, e, yes, shit, suitcase,
# Nearest to who: speak, gillies, bugsy, boziz, weu, duckling, unido, promiscuous,
# Nearest to known: redirects, ecclesiasticus, as, typically, varying, ensembl, are, today,
# Nearest to about: looking, time, minute, estimated, pampa, fieldwork, examining, relena,
# Nearest to from: the, of, and, a, in, much, at, have,
# Nearest to also: for, of, and, the, in, as, a, is,
# Nearest to and: the, of, for, in, with, a, also, as,
# Nearest to many: such, other, well, most, were, onwards, although, some,
# Nearest to institute: university, technology, nanyang, polytechnic, resolution, carolina, quark, penzias,
# Nearest to derived: frysl, mia, implies, name, consist, word, pronominal, scullard,
# Nearest to defense: summarize, taverne, weapons, schottenheimer, offense, defence, phonetic, crows,
# Nearest to animals: animal, echinoderms, gunung, flagella, ascanian, wildlife, elective, grasping,
# Nearest to square: rss, humps, havel, outlying, dicots, nafs, inequalities, varphi,
# Nearest to hold: recoiled, landmark, creationists, replace, cater, disqualified, rabbis, fringed,
# Nearest to ice: hockey, ethnolinguistic, melts, hosting, frozen, should, skates, sheets,
# Nearest to articles: wikipedia, article, koopman, pornographic, sejong, issues, chaldea, detailed,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8319 0.3934 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8285 0.3883 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8862 0.3876 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8587 0.3888 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8442 0.3878 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8668 0.3884 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8480 0.3888 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8405 0.3878 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8826 0.4158 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8393 0.3889 sec/batch
# Nearest to i: my, you, t, we, yes, shit, outta, e,
# Nearest to who: boziz, speak, bugsy, kamatari, gillies, weu, descent, karamchand,
# Nearest to known: ecclesiasticus, redirects, as, varying, secant, they, among, today,
# Nearest to about: time, estimated, at, looking, pampa, fieldwork, minute, examining,
# Nearest to from: the, of, and, a, in, much, dominant, called,
# Nearest to also: of, and, for, the, in, as, is, a,
# Nearest to and: the, of, in, for, with, a, also, as,
# Nearest to many: such, were, most, onwards, other, although, well, some,
# Nearest to institute: university, technology, nanyang, polytechnic, resolution, carolina, penzias, emerged,
# Nearest to derived: frysl, name, mia, consist, implies, pronominal, meaning, easter,
# Nearest to defense: taverne, summarize, crows, defence, phonetic, offense, misconduct, participated,
# Nearest to animals: animal, echinoderms, flagella, gunung, elective, wildlife, ascanian, faunal,
# Nearest to square: rss, nafs, dicots, havel, humps, lunel, gatehouse, outlying,
# Nearest to hold: recoiled, creationists, landmark, rabbis, replace, cater, fringed, disqualified,
# Nearest to ice: hockey, ethnolinguistic, melts, frozen, hosting, should, skates, sheets,
# Nearest to articles: wikipedia, article, koopman, pornographic, sejong, chaldea, posted, substantive,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8912 0.3920 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8757 0.3884 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8166 0.3967 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8338 0.3883 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9090 0.3929 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8515 0.3958 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9672 0.3930 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8827 0.3923 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9517 0.3918 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8078 0.3927 sec/batch
# Nearest to i: my, you, we, t, e, outta, yes, suitcase,
# Nearest to who: speak, boziz, gillies, descent, lathe, weu, bugsy, kamatari,
# Nearest to known: ecclesiasticus, styne, today, redirects, as, vietnam, varying, distinctive,
# Nearest to about: time, zero, at, looking, estimated, minute, of, people,
# Nearest to from: the, and, of, to, in, a, much, by,
# Nearest to also: of, for, and, the, in, a, as, see,
# Nearest to and: the, of, in, for, with, a, as, also,
# Nearest to many: such, most, were, other, some, onwards, although, well,
# Nearest to institute: university, technology, nanyang, polytechnic, resolution, penzias, quark, carolina,
# Nearest to derived: frysl, mia, name, consist, word, everyday, implies, pronominal,
# Nearest to defense: taverne, summarize, weapons, phonetic, defence, participated, crows, inhumane,
# Nearest to animals: animal, flagella, gunung, echinoderms, elective, ascanian, faunal, wildlife,
# Nearest to square: rss, havel, dicots, humps, inequalities, kilometers, lunel, nafs,
# Nearest to hold: recoiled, creationists, replace, rabbis, landmark, disqualified, fringed, parties,
# Nearest to ice: hockey, ethnolinguistic, melts, skates, hosting, frozen, sheets, pardubice,
# Nearest to articles: wikipedia, sejong, article, pornographic, koopman, chaldea, substantive, posted,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7694 0.3948 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8757 0.3923 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8115 0.3935 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8729 0.3936 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8720 0.3926 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8430 0.3922 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9080 0.1894 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8331 0.3928 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8514 0.3938 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8579 0.3941 sec/batch
# Nearest to i: my, you, we, t, outta, yes, danzig, suitcase,
# Nearest to who: speak, boziz, gillies, descent, bugsy, lathe, promiscuous, karamchand,
# Nearest to known: as, today, are, ecclesiasticus, varying, among, distinctive, styne,
# Nearest to about: time, at, of, zero, estimated, looking, people, minute,
# Nearest to from: the, of, and, a, to, in, much, with,
# Nearest to also: of, for, and, the, in, is, a, as,
# Nearest to and: the, of, in, with, a, for, as, to,
# Nearest to many: such, other, most, were, some, although, are, onwards,
# Nearest to institute: university, technology, nanyang, polytechnic, resolution, penzias, quark, emerged,
# Nearest to derived: frysl, name, mia, everyday, implies, consist, undisturbed, chemins,
# Nearest to defense: taverne, summarize, weapons, offense, crows, phonetic, defence, schottenheimer,
# Nearest to animals: animal, flagella, gunung, echinoderms, elective, faunal, wildlife, ascanian,
# Nearest to square: rss, humps, dicots, inequalities, raya, havel, outlying, gatehouse,
# Nearest to hold: recoiled, creationists, replace, rabbis, landmark, fringed, cater, admire,
# Nearest to ice: hockey, ethnolinguistic, melts, hosting, frozen, skates, sheets, pardubice,
# Nearest to articles: wikipedia, article, sejong, pornographic, koopman, substantive, chaldea, posted,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8489 0.3954 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8257 0.3921 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8358 0.3912 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7811 0.3910 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8689 0.3910 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8310 0.3901 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8793 0.3903 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7613 0.3919 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7981 0.3898 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7867 0.3902 sec/batch
# Nearest to i: my, you, we, t, yes, neatly, dxf, outta,
# Nearest to who: speak, boziz, descent, lathe, kamatari, weu, gillies, promiscuous,
# Nearest to known: as, today, ecclesiasticus, distinctive, are, among, vietnam, they,
# Nearest to about: time, zero, estimated, of, five, at, largest, pampa,
# Nearest to from: the, and, of, a, in, to, much, by,
# Nearest to also: of, for, and, in, the, as, a, is,
# Nearest to and: the, of, in, for, a, with, also, as,
# Nearest to many: other, such, most, some, are, although, that, were,
# Nearest to institute: university, technology, nanyang, resolution, polytechnic, quark, penzias, similarities,
# Nearest to derived: frysl, name, consist, implies, mia, everyday, meaning, metric,
# Nearest to defense: taverne, summarize, weapons, schottenheimer, offense, phonetic, crows, defence,
# Nearest to animals: animal, gunung, echinoderms, flagella, wildlife, faunal, elective, ascanian,
# Nearest to square: rss, humps, inequalities, outlying, havel, dicots, gatehouse, downtown,
# Nearest to hold: creationists, landmark, recoiled, replace, cater, rabbis, disqualified, fringed,
# Nearest to ice: hockey, ethnolinguistic, frozen, melts, hosting, skates, sheets, pardubice,
# Nearest to articles: wikipedia, article, koopman, sejong, pornographic, chaldea, detailed, substantive,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7555 0.3920 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8194 0.3898 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8339 0.3913 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8348 0.3910 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8041 0.3900 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8789 0.3903 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8538 0.3915 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8239 0.3900 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8109 0.3908 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8431 0.3909 sec/batch
# Nearest to i: my, you, we, t, outta, yes, e, suitcase,
# Nearest to who: boziz, speak, descent, oecs, weu, unido, bugsy, unmop,
# Nearest to known: as, ecclesiasticus, today, vietnam, styne, are, they, redirects,
# Nearest to about: time, looking, estimated, at, minute, wyoming, people, of,
# Nearest to from: the, and, of, a, in, to, much, also,
# Nearest to also: of, and, for, the, in, a, as, is,
# Nearest to and: the, of, in, for, a, as, also, with,
# Nearest to many: other, such, most, some, were, although, are, well,
# Nearest to institute: university, technology, nanyang, polytechnic, resolution, penzias, quark, emerged,
# Nearest to derived: frysl, name, mia, implies, meaning, consist, word, pronominal,
# Nearest to defense: taverne, summarize, defence, weapons, crows, phonetic, sacro, inhumane,
# Nearest to animals: animal, flagella, gunung, elective, echinoderms, wildlife, faunal, fungi,
# Nearest to square: rss, inequalities, humps, scruton, dicots, havel, per, raya,
# Nearest to hold: recoiled, creationists, landmark, replace, rabbis, cater, fringed, adjoin,
# Nearest to ice: hockey, ethnolinguistic, frozen, melts, hosting, skates, sheets, riverbed,
# Nearest to articles: wikipedia, article, koopman, sejong, pornographic, chaldea, really, detailed,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8884 0.3955 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8221 0.3901 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8080 0.3922 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8528 0.3901 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8800 0.3901 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8656 0.3925 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8397 0.3910 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8324 0.3923 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8213 0.3919 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8172 0.4008 sec/batch
# Nearest to i: my, you, t, we, sopron, yes, e, outta,
# Nearest to who: speak, boziz, descent, weu, kamatari, lathe, bugsy, oecs,
# Nearest to known: as, ecclesiasticus, they, distinctive, styne, vietnam, today, among,
# Nearest to about: time, zero, estimated, five, at, of, people, wyoming,
# Nearest to from: the, and, of, a, in, to, much, with,
# Nearest to also: of, and, for, the, a, in, as, see,
# Nearest to and: the, of, in, for, a, with, as, to,
# Nearest to many: such, some, were, other, most, although, as, and,
# Nearest to institute: university, technology, nanyang, polytechnic, resolution, penzias, quark, emerged,
# Nearest to derived: frysl, name, mia, meaning, implies, word, everyday, pronominal,
# Nearest to defense: taverne, summarize, weapons, defence, phonetic, crows, sacro, inhumane,
# Nearest to animals: animal, flagella, wildlife, gunung, elective, echinoderms, faunal, horse,
# Nearest to square: rss, inequalities, scruton, humps, dicots, lunel, raya, nafs,
# Nearest to hold: creationists, recoiled, replace, rabbis, fringed, landmark, cater, disqualified,
# Nearest to ice: hockey, ethnolinguistic, frozen, melts, hosting, skates, pardubice, sheets,
# Nearest to articles: wikipedia, article, sejong, koopman, pornographic, issues, chaldea, posted,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8640 0.3956 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8119 0.3942 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9131 0.3940 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9271 0.3923 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8882 0.3906 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8496 0.3915 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8213 0.3892 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8073 0.3899 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7659 0.3912 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8646 0.3927 sec/batch
# Nearest to i: my, you, we, t, yes, suitcase, sopron, outta,
# Nearest to who: speak, boziz, lathe, descent, bugsy, gillies, literacy, weu,
# Nearest to known: as, are, today, they, distinctive, styne, ecclesiasticus, varying,
# Nearest to about: time, at, people, of, estimated, looking, zero, there,
# Nearest to from: the, and, of, a, in, to, with, by,
# Nearest to also: of, and, the, for, a, in, as, is,
# Nearest to and: the, of, in, a, for, with, as, also,
# Nearest to many: most, other, such, some, were, although, an, are,
# Nearest to institute: technology, university, nanyang, resolution, polytechnic, penzias, quark, emerged,
# Nearest to derived: frysl, name, meaning, implies, mia, everyday, word, origin,
# Nearest to defense: taverne, summarize, weapons, defence, phonetic, crows, sacro, diedrich,
# Nearest to animals: animal, wildlife, gunung, elective, flagella, faunal, ascanian, grasping,
# Nearest to square: rss, humps, inequalities, scruton, kilometers, havel, raya, lunel,
# Nearest to hold: creationists, rabbis, recoiled, landmark, replace, disqualified, cater, fringed,
# Nearest to ice: hockey, ethnolinguistic, frozen, melts, hosting, sheets, pardubice, skates,
# Nearest to articles: wikipedia, article, sejong, pornographic, koopman, chaldea, issues, posted,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8300 0.3949 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8432 0.3916 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
